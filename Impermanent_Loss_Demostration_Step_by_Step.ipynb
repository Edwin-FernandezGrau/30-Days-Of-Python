# %% [markdown]
# <a href="https://colab.research.google.com/github/Edwin-FernandezGrau/30-Days-Of-Python/blob/master/Impermanent_Loss_Demostration_Step_by_Step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Impermante Loss

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
d = np.linspace(0,5,1000)
plt.figure(figsize=(12, 6))
plt.plot(d,((d**0.5)*(1**0.5))/(0.5*d + 0.5*1)-1,label = "50/50")
plt.xlabel('Relative Price Change') 
plt.ylabel('Impermanent Loss') 
plt.title("Losses due to price variation")
plt.grid(linestyle='--')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
d = np.linspace(0,5,1000)
plt.figure(figsize=(12, 6))
plt.plot(d,((d**0.8)*(1**0.2))/(0.8*d + 0.2*1)-1,label = "80/20")
plt.plot(d,((d**0.95)*(1**0.05))/(0.95*d + 0.05*1)-1,label = "95/5")
plt.plot(d,((d**0.5)*(1**0.5))/(0.5*d + 0.5*1)-1,label = "50/50")
plt.xlabel('Relative Price Change') 
plt.ylabel('Impermanent Loss') 
plt.title("Losses due to price variation")
plt.grid(linestyle='--')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
